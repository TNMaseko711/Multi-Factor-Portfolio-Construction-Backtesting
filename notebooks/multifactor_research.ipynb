# %% [markdown]
# # Multi-Factor Portfolio Construction & Backtesting\nThis notebook demonstrates the full research workflow.

# %%
# !python run_backtest.py --start 2015-01-01 --end 2024-12-31 --rebalance M --method score_weighted

# %%
import pandas as pd\nsummary = pd.read_csv('outputs/performance_summary.csv')\nsummary.head()
